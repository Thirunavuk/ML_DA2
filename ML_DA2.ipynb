# %%
import os
os.chdir("D:\SEM - 6\Machine Learning")

# %%
import pandas as pd
import numpy as np
df=pd.read_csv("complete_file1.csv")

# %%
df.isnull().sum()
# Out:
# Unnamed: 0       0
# file_name        0
# suspicious       0
# data            45
# cleaned_data    44
# dtype: int64

# %%
df1=df.dropna()
df1
# Out:
#       Unnamed: 0                      file_name  suspicious  \
# 18            18                         59.txt        True
# 27            27                   story836.txt        True
# 29            29  238-sexworkershumanrights.txt        True
# 30            30                   story520.txt        True
# 35            35     163-natonuclearrelapse.txt        True
# ...          ...                            ...         ...
# 1477        1477                   story470.txt       False
# 1478        1478                   story468.txt       False
# 1479        1479                   story864.txt       False
# 1480        1480                    story24.txt       False
# 1481        1481                   story523.txt       False
#
#                                                    data  \
# 18    Ransomware attacks on Colonial Pipeline, JBS F...
# 27    Bomb case highlights 'lone-wolf' fears\nAmine ...
# 29    In a case brought by three sex workers, the Su...
# ...

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0      0
# file_name       0
# suspicious      0
# data            0
# cleaned_data    0
# dtype: int64

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer= CountVectorizer()

# %%
vectorizer.fit(df1['cleaned_data'])
# Out:
# CountVectorizer()

# %%
vectorizer.vocabulary_
# Out:
# {'ransomware': 23073,
#  'attack': 2743,
#  'colonial': 6041,
#  'pipeline': 21510,
#  'jbs': 15499,
#  'foods': 11476,
#  'major': 17451,
#  'organization': 20305,
#  'headline': 13272,
#  '2021': 377,
#  'sign': 26040,
#  'slowing': 26327,
#  'across': 1221,
#  'world': 31406,
#  'hacker': 12889,
#  'exploiting': 10565,
#  'security': 25406,
#  'weakness': 30927,
#  'holding': 13651,
#  'data': 7561,
#  'company': 6197,
#  'government': 12513,
#  'healthcare': 13289,
#  'hostage': 13813,
#  'demanding': 7962,
#  'ten': 28345,
#  'million': 18332,
#  'dollar': 8957,
#  'payment': 21039,
#  'according': 1134,
#  'governmentâ': 12517,
#  'cybersecurity': 7403,
#  'infrastructure': 14717,
#  'assurance': 2680,
#  'agency': 1528,
#  'cisa': 5653,
#  'evolving': 10356,
#  'form': 11575,
#  'malware': 17513,
#  'designed': 8199,
#  'encrypt': 9862,
#  'file': 11124,
#  'device': 8322,
#  'rendering': 23805,
#  'system': 27990,
#  'rely': 23745,
#  'unusable': 30059,
# ...

# %%
newvec= vectorizer.transform(df1['cleaned_data'])

# %%
X=newvec.toarray()

# %%
on_hot_encoded=pd.get_dummies(df1.suspicious)
df1=pd.concat([df1,on_hot_encoded],axis='columns')
df1
# Out:
#       Unnamed: 0                      file_name  suspicious  \
# 18            18                         59.txt        True
# 27            27                   story836.txt        True
# 29            29  238-sexworkershumanrights.txt        True
# 30            30                   story520.txt        True
# 35            35     163-natonuclearrelapse.txt        True
# ...          ...                            ...         ...
# 1477        1477                   story470.txt       False
# 1478        1478                   story468.txt       False
# 1479        1479                   story864.txt       False
# 1480        1480                    story24.txt       False
# 1481        1481                   story523.txt       False
#
#                                                    data  \
# 18    Ransomware attacks on Colonial Pipeline, JBS F...
# 27    Bomb case highlights 'lone-wolf' fears\nAmine ...
# 29    In a case brought by three sex workers, the Su...
# ...

# %%
y=df1[1]
y
# Out:
# 18      1
# 27      1
# 29      1
# 30      1
# 35      1
#        ..
# 1477    0
# 1478    0
# 1479    0
# 1480    0
# 1481    0
# Name: True, Length: 1431, dtype: uint8

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.3,random_state=0)

# %%
from sklearn.svm import SVC
model1 = SVC(random_state=0)
model1.fit(X_train,y_train)
# Out:
# SVC(random_state=0)

# %%
model1.score(X_test,y_test)
# Out:
# 0.8488372093023255

# %%
svc_linear = SVC(kernel = 'linear').fit(X_train, y_train)
print("Linear",svc_linear.score(X_test,y_test))

svc_rbf = SVC(kernel = 'rbf').fit(X_train, y_train)
print("Rbf", svc_poly.score(X_test,y_test))

svc_poly = SVC(kernel = 'poly').fit(X_train, y_train)
print("Poly", svc_poly.score(X_test,y_test))

svc_sigmoid = SVC(kernel = 'sigmoid').fit(X_train, y_train)
print("sigmoid", svc_poly.score(X_test,y_test))
# Out:
# Linear 0.8441860465116279
# Rbf 0.813953488372093
# Poly 0.672093023255814
# sigmoid 0.672093023255814

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler 
from sklearn.svm import SVC
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import load_iris
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.metrics import precision_recall_fscore_support, classification_report, confusion_matrix, plot_confusion_matrix
pred=svc_linear.predict(X_test)
print(classification_report(y_test, pred))
pred=svc_rbf.predict(X_test)
print(classification_report(y_test, pred))
pred=svc_poly.predict(X_test)
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.90      0.86       225
#            1       0.88      0.78      0.83       205
#
#     accuracy                           0.84       430
#    macro avg       0.85      0.84      0.84       430
# weighted avg       0.85      0.84      0.84       430
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.90      0.86       225
#            1       0.88      0.80      0.83       205
#
#     accuracy                           0.85       430
#    macro avg       0.85      0.85      0.85       430
# weighted avg       0.85      0.85      0.85       430
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.98      0.76       225
#            1       0.93      0.34      0.49       205
#
#     accuracy                           0.67       430
#    macro avg       0.78      0.66      0.63       430
# ...

# %%
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier(random_state=42).fit(X_train, y_train)
clf.score(X_test,y_test)
# Out:
# 0.8069767441860465

# %%
pred=clf.predict(X_test)
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.82      0.82       225
#            1       0.80      0.80      0.80       205
#
#     accuracy                           0.81       430
#    macro avg       0.81      0.81      0.81       430
# weighted avg       0.81      0.81      0.81       430

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(max_depth=4,n_estimators=100,random_state=42).fit(X_train, y_train.values.ravel())

print('RF Accuracy on test set: {:.2f}'.format(clf.score(X_test, y_test)))
# Out:
# RF Accuracy on test set: 0.83

# %%
pred=clf.predict(X_test)
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.92      0.85       225
#            1       0.90      0.74      0.81       205
#
#     accuracy                           0.83       430
#    macro avg       0.85      0.83      0.83       430
# weighted avg       0.84      0.83      0.83       430
